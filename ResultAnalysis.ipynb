# %% [markdown]
# # Analisi dei risultati

# %% [markdown]
# Questa è una sintesi dei risultati ottenuti.

# %%
import matplotlib.pyplot as plt
from PIL import Image

# %% [markdown]
# # Consumo in fase di training

# %%
# Carica le immagini dei grafici del peso dei modelli
img1 = Image.open("CompasDataset/output/consumo_scores.png")
img2 = Image.open("GermanDataset/output/consumo_scores.png")
img3 = Image.open("SmsSpamDataset/output/consumo_scores.png")

fig, axs = plt.subplots(1, 3, figsize=(22, 10))

axs[0].imshow(img1)
axs[0].axis('off')
axs[0].set_title('Compas')

axs[1].imshow(img2)
axs[1].axis('off')
axs[1].set_title('German')

axs[2].imshow(img3)
axs[2].axis('off')
axs[2].set_title('SmsSpam')

plt.tight_layout() 
plt.show()

# %% [markdown]
# # Peso modelli

# %%
# Carica le immagini dei grafici del peso dei modelli
img1 = Image.open("CompasDataset/output/peso_modello_accuratezza.png")
img2 = Image.open("GermanDataset/output/peso_modello_accuratezza.png")
img3 = Image.open("SmsSpamDataset/output/peso_modello_accuratezza.png")

fig, axs = plt.subplots(1, 3, figsize=(22, 10))

axs[0].imshow(img1)
axs[0].axis('off')
axs[0].set_title('Compas')

axs[1].imshow(img2)
axs[1].axis('off')
axs[1].set_title('German')

axs[2].imshow(img3)
axs[2].axis('off')
axs[2].set_title('SmsSpam')

plt.tight_layout() 
plt.show()

# %% [markdown]
# # Consumo energetico

# %%
# Carica le immagini dei grafici del consumo dei modelli
img1 = Image.open("CompasDataset/output/consumo_energia_accuratezza.png")
img2 = Image.open("GermanDataset/output/consumo_energia_accuratezza.png")
img3 = Image.open("SmsSpamDataset/output/consumo_energia_accuratezza.png")

fig, axs = plt.subplots(1, 3, figsize=(22, 10))

axs[0].imshow(img1)
axs[0].axis('off')
axs[0].set_title('Compas')

axs[1].imshow(img2)
axs[1].axis('off')
axs[1].set_title('German')

axs[2].imshow(img3)
axs[2].axis('off')
axs[2].set_title('SmsSpam')

plt.tight_layout() 
plt.show()

# %% [markdown]
# I risultati sono pienamentte in correlazione con lo studio di jarvpenaa, che dice che ad esempio il KNN consuma più energia rispetto al Random Forest. O ad esempio SVM lavorando con iperpiani è uno degli algortimi di ML più costosi a livello energetico. E così via.

# %% [markdown]
# # Tempo inferenza

# %%
# Carica le immagini dei grafici del tempo inferenza dei modelli
img1 = Image.open("CompasDataset/output/tempo_inferenza_accuratezza.png")
img2 = Image.open("GermanDataset/output/tempo_inferenza_accuratezza.png")
img3 = Image.open("SmsSpamDataset/output/tempo_inferenza_accuratezza.png")

fig, axs = plt.subplots(1, 3, figsize=(22, 10))

axs[0].imshow(img1)
axs[0].axis('off')
axs[0].set_title('Compas')

axs[1].imshow(img2)
axs[1].axis('off')
axs[1].set_title('German')

axs[2].imshow(img3)
axs[2].axis('off')
axs[2].set_title('SmsSpam')

plt.tight_layout() 
plt.show()

# %% [markdown]
# SVM essendo un algoritmo molto complesso, ha spesso un tempo di inferenza maggiore rispetto ad algortimi più semplici, come il DCT.

# %% [markdown]
# # Utilizzo CPU

# %%
# Carica le immagini dei grafici del consumo CPU dei modelli
img1 = Image.open("CompasDataset/output/utilizzo_cpu_accuratezza.png")
img2 = Image.open("GermanDataset/output/utilizzo_cpu_accuratezza.png")
img3 = Image.open("SmsSpamDataset/output/utilizzo_cpu_accuratezza.png")

fig, axs = plt.subplots(1, 3, figsize=(22, 10))

axs[0].imshow(img1)
axs[0].axis('off')
axs[0].set_title('Compas')

axs[1].imshow(img2)
axs[1].axis('off')
axs[1].set_title('German')

axs[2].imshow(img3)
axs[2].axis('off')
axs[2].set_title('SmsSpam')

plt.tight_layout() 
plt.show()

# %% [markdown]
# # Utilizzo memoria

# %%
# Carica le immagini dei grafici del consumo memoria dei modelli
img1 = Image.open("CompasDataset/output/utilizzo_memoria_accuratezza.png")
img2 = Image.open("GermanDataset/output/utilizzo_memoria_accuratezza.png")
img3 = Image.open("SmsSpamDataset/output/utilizzo_memoria_accuratezza.png")

fig, axs = plt.subplots(1, 3, figsize=(22, 10))

axs[0].imshow(img1)
axs[0].axis('off')
axs[0].set_title('Compas')

axs[1].imshow(img2)
axs[1].axis('off')
axs[1].set_title('German')

axs[2].imshow(img3)
axs[2].axis('off')
axs[2].set_title('SmsSpam')

plt.tight_layout() 
plt.show()

# %% [markdown]
# # Correlazione feature

# %%
# Carica le immagini delle confusion matrix
img1 = Image.open("CompasDataset/output/matrice_correlazione.png")
img2 = Image.open("GermanDataset/output/matrice_correlazione.png")
img3 = Image.open("SmsSpamDataset/output/matrice_correlazione.png")

fig, axs = plt.subplots(1, 3, figsize=(22, 10))

axs[0].imshow(img1)
axs[0].axis('off')
axs[0].set_title('Compas')

axs[1].imshow(img2)
axs[1].axis('off')
axs[1].set_title('German')

axs[2].imshow(img3)
axs[2].axis('off')
axs[2].set_title('SmsSpam')

plt.tight_layout() 
plt.show()

# %% [markdown]
# Queste qui sopra sono le 3 confusion matrix, ottenute dai 3 differenti dataset (dove per ognuno abbaimo più modelli che usano differenti algoritmi). Ovviamente si può notare che le correlazioni cambiano da dataset a dataset, proprio perchè i dataset sono eterogei tra di loro, per grandezza e contenuti.
#
# Andiamo a fare un'analisi della correlazione, di ogni variabile con l'accuratezza...

# %%
import pandas as pd

df_Compas = pd.read_csv("CompasDataset/output/results_correlazione.csv")
df_German = pd.read_csv("GermanDataset/output/results_correlazione.csv")
df_Sms = pd.read_csv("SmsSpamDataset/output/results_correlazione.csv")

# %%
#stampo i df 
df_German_senza_variabile = df_German["Correlazione con Accuratezza"]
df_Sms_senza_variabile = df_Sms["Correlazione con Accuratezza"]

# Concatena i dataframe insieme, mantenendo solo la colonna "Variabile" all'inizio
df_concatenato = pd.concat([df_Compas, df_German_senza_variabile, df_Sms_senza_variabile], axis=1)

# Mostra il dataframe concatenato
print(df_concatenato)
# Out:
#                Variabile  Correlazione con Accuratezza  \
# 0       Utilizzo CPU (%)                      0.246691
# 1   Utilizzo memoria (%)                      0.436272
# 2    Tempo inferenza (s)                      0.674081
# 3    Consumo energia (J)                      0.676418
# 4  Peso del modello (KB)                     -0.009963
#
#    Correlazione con Accuratezza  Correlazione con Accuratezza
# 0                     -0.648047                     -0.295918
# 1                     -0.362976                     -0.360684
# 2                     -0.035408                     -0.560644
# 3                     -0.019336                     -0.659646
# 4                      0.138533                      0.555811

# %% [markdown]
# Queste qui sopra sono le correlazioni di ogni variabile con l'accuratezza. Ora ne faccio una media.

# %%
# Calcolo della media delle correlazioni per variabile (riga)
df_concatenato['Media_correlazioni'] = df_concatenato.iloc[:, 1:].mean(axis=1)
print(df_concatenato['Media_correlazioni'])
# Out:
# 0   -0.232425
# 1   -0.095796
# 2    0.026010
# 3   -0.000855
# 4    0.228127
# Name: Media_correlazioni, dtype: float64

# %% [markdown]
# In generale, vedendo i risultati, posso concludere che nel mio studio ho notato scarsa correlazione tra accuratezza e le variabili calcolate.
